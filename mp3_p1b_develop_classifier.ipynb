# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuhaocn/image_recognition/blob/main/mp3_p1b_develop_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# %cd '/content/drive/My Drive/Colab Notebooks/Final Project/'
# !pwd
# Out:
# Mounted at /content/drive
# /content
# /content/drive/My Drive/Colab Notebooks/Final Project
# /content/drive/My Drive/Colab Notebooks/Final Project

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.RandomResizedCrop(227),
            transforms.RandomApply(torch.nn.ModuleList([transforms.RandomHorizontalFlip(),transforms.RandomVerticalFlip(),transforms.RandomRotation(25)])),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.RandomResizedCrop(227),
            transforms.RandomApply(torch.nn.ModuleList([transforms.RandomHorizontalFlip(),transforms.RandomVerticalFlip(),transforms.RandomRotation(25)])),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)
# Out:
# /content/drive/MyDrive/Colab Notebooks/Final Project/voc_dataloader.py:137: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(box_indices),

# %%
num_epochs = 150
test_frequency = 5
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
from numpy.core.numeric import tensordot
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
#optimizer = torch.optim.SGD(classifier.parameters(), lr=0.001, momentum=0.9)
optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4,weight_decay=1e-4)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.34453150629997253
# -------  Class: aeroplane        AP:   0.2025  -------
# -------  Class: bicycle          AP:   0.0777  -------
# -------  Class: bird             AP:   0.0692  -------
# -------  Class: boat             AP:   0.0465  -------
# -------  Class: bottle           AP:   0.0626  -------
# -------  Class: bus              AP:   0.0498  -------
# -------  Class: car              AP:   0.2287  -------
# -------  Class: cat              AP:   0.0987  -------
# -------  Class: chair            AP:   0.1573  -------
# -------  Class: cow              AP:   0.0327  -------
# -------  Class: diningtable      AP:   0.0941  -------
# -------  Class: dog              AP:   0.1091  -------
# -------  Class: horse            AP:   0.0860  -------
# -------  Class: motorbike        AP:   0.0988  -------
# -------  Class: person           AP:   0.4963  -------
# -------  Class: pottedplant      AP:   0.0694  -------
# -------  Class: sheep            AP:   0.0196  -------
# -------  Class: sofa             AP:   0.1107  -------
# -------  Class: train            AP:   0.0757  -------
# -------  Class: tvmonitor        AP:   0.0721  -------
# mAP: 0.1129
# Avg loss: 0.2376410633325577
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.11288067881414206
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.22878746688365936
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.22313563525676727
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.21853554248809814
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.21521973609924316
# -------  Class: aeroplane        AP:   0.3791  -------
# -------  Class: bicycle          AP:   0.1113  -------
# -------  Class: bird             AP:   0.1151  -------
# -------  Class: boat             AP:   0.1751  -------
# -------  Class: bottle           AP:   0.0875  -------
# -------  Class: bus              AP:   0.0892  -------
# -------  Class: car              AP:   0.3788  -------
# -------  Class: cat              AP:   0.1850  -------
# -------  Class: chair            AP:   0.2875  -------
# -------  Class: cow              AP:   0.0796  -------
# -------  Class: diningtable      AP:   0.1127  -------
# -------  Class: dog              AP:   0.1614  -------
# -------  Class: horse            AP:   0.1405  -------
# -------  Class: motorbike        AP:   0.1213  -------
# -------  Class: person           AP:   0.5760  -------
# -------  Class: pottedplant      AP:   0.1026  -------
# -------  Class: sheep            AP:   0.0840  -------
# -------  Class: sofa             AP:   0.1471  -------
# -------  Class: train            AP:   0.1391  -------
# -------  Class: tvmonitor        AP:   0.0993  -------
# mAP: 0.1786
# Avg loss: 0.2145135100930929
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.17860682462721908
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.2106471061706543
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.20735357701778412
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2073306143283844
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2055554836988449
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.20181654393672943
# -------  Class: aeroplane        AP:   0.4713  -------
# -------  Class: bicycle          AP:   0.2068  -------
# -------  Class: bird             AP:   0.1397  -------
# -------  Class: boat             AP:   0.1335  -------
# -------  Class: bottle           AP:   0.1059  -------
# -------  Class: bus              AP:   0.1445  -------
# -------  Class: car              AP:   0.4110  -------
# -------  Class: cat              AP:   0.2309  -------
# -------  Class: chair            AP:   0.2749  -------
# -------  Class: cow              AP:   0.0883  -------
# -------  Class: diningtable      AP:   0.1997  -------
# -------  Class: dog              AP:   0.2011  -------
# -------  Class: horse            AP:   0.2785  -------
# -------  Class: motorbike        AP:   0.2178  -------
# -------  Class: person           AP:   0.6552  -------
# -------  Class: pottedplant      AP:   0.1635  -------
# -------  Class: sheep            AP:   0.0951  -------
# -------  Class: sofa             AP:   0.1670  -------
# -------  Class: train            AP:   0.1659  -------
# -------  Class: tvmonitor        AP:   0.1104  -------
# mAP: 0.2230
# Avg loss: 0.2056736659258604
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.2230466547779013
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.20277798175811768
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.1976960450410843
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.19805291295051575
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.19201616942882538
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.19317646324634552
# -------  Class: aeroplane        AP:   0.4906  -------
# -------  Class: bicycle          AP:   0.2395  -------
# -------  Class: bird             AP:   0.1498  -------
# -------  Class: boat             AP:   0.2591  -------
# -------  Class: bottle           AP:   0.1092  -------
# -------  Class: bus              AP:   0.1875  -------
# -------  Class: car              AP:   0.4690  -------
# -------  Class: cat              AP:   0.2709  -------
# -------  Class: chair            AP:   0.3248  -------
# -------  Class: cow              AP:   0.0849  -------
# -------  Class: diningtable      AP:   0.2330  -------
# -------  Class: dog              AP:   0.2174  -------
# -------  Class: horse            AP:   0.3005  -------
# -------  Class: motorbike        AP:   0.2667  -------
# -------  Class: person           AP:   0.6540  -------
# -------  Class: pottedplant      AP:   0.1671  -------
# -------  Class: sheep            AP:   0.1200  -------
# -------  Class: sofa             AP:   0.1881  -------
# -------  Class: train            AP:   0.2651  -------
# -------  Class: tvmonitor        AP:   0.2047  -------
# mAP: 0.2601
# Avg loss: 0.20048395320773124
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2600908713901505
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.19076859951019287
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.19214081764221191
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.19169817864894867
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.19045579433441162
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1855684071779251
# -------  Class: aeroplane        AP:   0.4938  -------
# -------  Class: bicycle          AP:   0.2694  -------
# -------  Class: bird             AP:   0.1805  -------
# -------  Class: boat             AP:   0.2746  -------
# -------  Class: bottle           AP:   0.1187  -------
# -------  Class: bus              AP:   0.2032  -------
# -------  Class: car              AP:   0.4704  -------
# -------  Class: cat              AP:   0.2521  -------
# -------  Class: chair            AP:   0.3887  -------
# -------  Class: cow              AP:   0.0836  -------
# -------  Class: diningtable      AP:   0.2923  -------
# -------  Class: dog              AP:   0.2580  -------
# -------  Class: horse            AP:   0.3407  -------
# -------  Class: motorbike        AP:   0.3795  -------
# -------  Class: person           AP:   0.6927  -------
# -------  Class: pottedplant      AP:   0.1376  -------
# -------  Class: sheep            AP:   0.1174  -------
# -------  Class: sofa             AP:   0.2869  -------
# -------  Class: train            AP:   0.3460  -------
# -------  Class: tvmonitor        AP:   0.2238  -------
# mAP: 0.2905
# Avg loss: 0.19442896731197834
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.2904902416770609
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.1850161850452423
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.18352781236171722
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.18173138797283173
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.1806788295507431
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.18066780269145966
# -------  Class: aeroplane        AP:   0.4582  -------
# -------  Class: bicycle          AP:   0.2491  -------
# -------  Class: bird             AP:   0.2152  -------
# -------  Class: boat             AP:   0.2883  -------
# -------  Class: bottle           AP:   0.1023  -------
# -------  Class: bus              AP:   0.1963  -------
# -------  Class: car              AP:   0.4907  -------
# -------  Class: cat              AP:   0.3013  -------
# -------  Class: chair            AP:   0.3371  -------
# -------  Class: cow              AP:   0.0977  -------
# -------  Class: diningtable      AP:   0.2744  -------
# -------  Class: dog              AP:   0.2555  -------
# -------  Class: horse            AP:   0.4028  -------
# -------  Class: motorbike        AP:   0.3206  -------
# -------  Class: person           AP:   0.6979  -------
# -------  Class: pottedplant      AP:   0.1794  -------
# -------  Class: sheep            AP:   0.1408  -------
# -------  Class: sofa             AP:   0.2194  -------
# -------  Class: train            AP:   0.3618  -------
# -------  Class: tvmonitor        AP:   0.2255  -------
# mAP: 0.2907
# Avg loss: 0.19504088200628758
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.290724777881084
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.17779168486595154
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.17716948688030243
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.1762332171201706
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.17376910150051117
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.1772017925977707
# -------  Class: aeroplane        AP:   0.5275  -------
# -------  Class: bicycle          AP:   0.2945  -------
# -------  Class: bird             AP:   0.1993  -------
# -------  Class: boat             AP:   0.3369  -------
# -------  Class: bottle           AP:   0.1052  -------
# -------  Class: bus              AP:   0.1669  -------
# -------  Class: car              AP:   0.4685  -------
# -------  Class: cat              AP:   0.2489  -------
# -------  Class: chair            AP:   0.3845  -------
# -------  Class: cow              AP:   0.1168  -------
# -------  Class: diningtable      AP:   0.2701  -------
# -------  Class: dog              AP:   0.2239  -------
# -------  Class: horse            AP:   0.4492  -------
# -------  Class: motorbike        AP:   0.3708  -------
# -------  Class: person           AP:   0.6936  -------
# -------  Class: pottedplant      AP:   0.1609  -------
# -------  Class: sheep            AP:   0.1156  -------
# -------  Class: sofa             AP:   0.2268  -------
# -------  Class: train            AP:   0.3799  -------
# -------  Class: tvmonitor        AP:   0.2215  -------
# mAP: 0.2981
# Avg loss: 0.19542024172842504
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.29806905659397864
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.1774521917104721
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.17284488677978516
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.17228560149669647
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.17218899726867676
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.17513425648212433
# -------  Class: aeroplane        AP:   0.5320  -------
# -------  Class: bicycle          AP:   0.3013  -------
# -------  Class: bird             AP:   0.2704  -------
# -------  Class: boat             AP:   0.2628  -------
# -------  Class: bottle           AP:   0.1157  -------
# -------  Class: bus              AP:   0.2072  -------
# -------  Class: car              AP:   0.5204  -------
# -------  Class: cat              AP:   0.3047  -------
# -------  Class: chair            AP:   0.3909  -------
# -------  Class: cow              AP:   0.1175  -------
# -------  Class: diningtable      AP:   0.2575  -------
# -------  Class: dog              AP:   0.2666  -------
# -------  Class: horse            AP:   0.4163  -------
# -------  Class: motorbike        AP:   0.3709  -------
# -------  Class: person           AP:   0.7273  -------
# -------  Class: pottedplant      AP:   0.1812  -------
# -------  Class: sheep            AP:   0.1499  -------
# -------  Class: sofa             AP:   0.2436  -------
# -------  Class: train            AP:   0.4045  -------
# -------  Class: tvmonitor        AP:   0.2004  -------
# mAP: 0.3121
# Avg loss: 0.19197997637093067
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.312054153828538
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.17121247947216034
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.16872070729732513
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.17237906157970428
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.17084376513957977
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.1692589670419693
# -------  Class: aeroplane        AP:   0.5135  -------
# -------  Class: bicycle          AP:   0.2781  -------
# -------  Class: bird             AP:   0.1790  -------
# -------  Class: boat             AP:   0.2418  -------
# -------  Class: bottle           AP:   0.1169  -------
# -------  Class: bus              AP:   0.1834  -------
# -------  Class: car              AP:   0.4819  -------
# -------  Class: cat              AP:   0.2943  -------
# -------  Class: chair            AP:   0.3813  -------
# -------  Class: cow              AP:   0.1531  -------
# -------  Class: diningtable      AP:   0.2463  -------
# -------  Class: dog              AP:   0.2292  -------
# -------  Class: horse            AP:   0.4380  -------
# -------  Class: motorbike        AP:   0.3039  -------
# -------  Class: person           AP:   0.7227  -------
# -------  Class: pottedplant      AP:   0.1360  -------
# -------  Class: sheep            AP:   0.1770  -------
# -------  Class: sofa             AP:   0.2433  -------
# -------  Class: train            AP:   0.4477  -------
# -------  Class: tvmonitor        AP:   0.2703  -------
# mAP: 0.3019
# Avg loss: 0.19120389707386493
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3018826129903176
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.16575899720191956
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.16911855340003967
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.16545306146144867
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.1632675677537918
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.1620844155550003
# -------  Class: aeroplane        AP:   0.5126  -------
# -------  Class: bicycle          AP:   0.2710  -------
# -------  Class: bird             AP:   0.2503  -------
# -------  Class: boat             AP:   0.2990  -------
# -------  Class: bottle           AP:   0.1280  -------
# -------  Class: bus              AP:   0.2227  -------
# -------  Class: car              AP:   0.5306  -------
# -------  Class: cat              AP:   0.2952  -------
# -------  Class: chair            AP:   0.4194  -------
# -------  Class: cow              AP:   0.1282  -------
# -------  Class: diningtable      AP:   0.3181  -------
# -------  Class: dog              AP:   0.2519  -------
# -------  Class: horse            AP:   0.3805  -------
# -------  Class: motorbike        AP:   0.4449  -------
# -------  Class: person           AP:   0.7217  -------
# -------  Class: pottedplant      AP:   0.1754  -------
# -------  Class: sheep            AP:   0.1284  -------
# -------  Class: sofa             AP:   0.2295  -------
# -------  Class: train            AP:   0.4387  -------
# -------  Class: tvmonitor        AP:   0.2495  -------
# mAP: 0.3198
# Avg loss: 0.19032417014241218
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.31979063180102935
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.16448013484477997
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.15995918214321136
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.16197402775287628
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.15920941531658173
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.16436176002025604
# -------  Class: aeroplane        AP:   0.5417  -------
# -------  Class: bicycle          AP:   0.2999  -------
# -------  Class: bird             AP:   0.2608  -------
# -------  Class: boat             AP:   0.3550  -------
# -------  Class: bottle           AP:   0.1152  -------
# -------  Class: bus              AP:   0.2356  -------
# -------  Class: car              AP:   0.5316  -------
# -------  Class: cat              AP:   0.3471  -------
# -------  Class: chair            AP:   0.4308  -------
# -------  Class: cow              AP:   0.1116  -------
# -------  Class: diningtable      AP:   0.2705  -------
# -------  Class: dog              AP:   0.2740  -------
# -------  Class: horse            AP:   0.4598  -------
# -------  Class: motorbike        AP:   0.4548  -------
# -------  Class: person           AP:   0.7401  -------
# -------  Class: pottedplant      AP:   0.1589  -------
# -------  Class: sheep            AP:   0.1427  -------
# -------  Class: sofa             AP:   0.2367  -------
# -------  Class: train            AP:   0.4855  -------
# -------  Class: tvmonitor        AP:   0.2730  -------
# mAP: 0.3363
# Avg loss: 0.18636234067380428
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.33626315122016853
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.16158261895179749
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.15774641931056976
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.15721462666988373
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.1582643985748291
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.15703783929347992
# -------  Class: aeroplane        AP:   0.5792  -------
# -------  Class: bicycle          AP:   0.3494  -------
# -------  Class: bird             AP:   0.2528  -------
# -------  Class: boat             AP:   0.3719  -------
# -------  Class: bottle           AP:   0.1330  -------
# -------  Class: bus              AP:   0.2679  -------
# -------  Class: car              AP:   0.5524  -------
# -------  Class: cat              AP:   0.2809  -------
# -------  Class: chair            AP:   0.3891  -------
# -------  Class: cow              AP:   0.1203  -------
# -------  Class: diningtable      AP:   0.2756  -------
# -------  Class: dog              AP:   0.2404  -------
# -------  Class: horse            AP:   0.3971  -------
# -------  Class: motorbike        AP:   0.4068  -------
# -------  Class: person           AP:   0.7372  -------
# -------  Class: pottedplant      AP:   0.1865  -------
# -------  Class: sheep            AP:   0.1355  -------
# -------  Class: sofa             AP:   0.2386  -------
# -------  Class: train            AP:   0.4606  -------
# -------  Class: tvmonitor        AP:   0.2577  -------
# mAP: 0.3316
# Avg loss: 0.18998179510235785
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.33164453245455716
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.1559094488620758
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.15696948766708374
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.1563313752412796
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.15660403668880463
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.15324394404888153
# -------  Class: aeroplane        AP:   0.5175  -------
# -------  Class: bicycle          AP:   0.3369  -------
# -------  Class: bird             AP:   0.2977  -------
# -------  Class: boat             AP:   0.2426  -------
# -------  Class: bottle           AP:   0.1289  -------
# -------  Class: bus              AP:   0.2431  -------
# -------  Class: car              AP:   0.5221  -------
# -------  Class: cat              AP:   0.3055  -------
# -------  Class: chair            AP:   0.3780  -------
# -------  Class: cow              AP:   0.1468  -------
# -------  Class: diningtable      AP:   0.2663  -------
# -------  Class: dog              AP:   0.2784  -------
# -------  Class: horse            AP:   0.4124  -------
# -------  Class: motorbike        AP:   0.3560  -------
# -------  Class: person           AP:   0.7048  -------
# -------  Class: pottedplant      AP:   0.1660  -------
# -------  Class: sheep            AP:   0.1717  -------
# -------  Class: sofa             AP:   0.2454  -------
# -------  Class: train            AP:   0.4468  -------
# -------  Class: tvmonitor        AP:   0.2986  -------
# mAP: 0.3233
# Avg loss: 0.19340927340090275
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.32327676332044925
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.1551259160041809
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.1537296622991562
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.15488329529762268
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.1546403467655182
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.15218093991279602
# -------  Class: aeroplane        AP:   0.5647  -------
# -------  Class: bicycle          AP:   0.3184  -------
# -------  Class: bird             AP:   0.2986  -------
# -------  Class: boat             AP:   0.3327  -------
# -------  Class: bottle           AP:   0.1473  -------
# -------  Class: bus              AP:   0.2239  -------
# -------  Class: car              AP:   0.5444  -------
# -------  Class: cat              AP:   0.3158  -------
# -------  Class: chair            AP:   0.3876  -------
# -------  Class: cow              AP:   0.1202  -------
# -------  Class: diningtable      AP:   0.3213  -------
# -------  Class: dog              AP:   0.2589  -------
# -------  Class: horse            AP:   0.4366  -------
# -------  Class: motorbike        AP:   0.4629  -------
# -------  Class: person           AP:   0.7419  -------
# -------  Class: pottedplant      AP:   0.1872  -------
# -------  Class: sheep            AP:   0.1596  -------
# -------  Class: sofa             AP:   0.2193  -------
# -------  Class: train            AP:   0.4206  -------
# -------  Class: tvmonitor        AP:   0.3355  -------
# mAP: 0.3399
# Avg loss: 0.1880495224148035
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.33986938731038824
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.15581141412258148
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.1508089303970337
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.15221600234508514
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.14641539752483368
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.15019933879375458
# -------  Class: aeroplane        AP:   0.5217  -------
# -------  Class: bicycle          AP:   0.3641  -------
# -------  Class: bird             AP:   0.2982  -------
# -------  Class: boat             AP:   0.3474  -------
# -------  Class: bottle           AP:   0.1261  -------
# -------  Class: bus              AP:   0.2229  -------
# -------  Class: car              AP:   0.4978  -------
# -------  Class: cat              AP:   0.3142  -------
# -------  Class: chair            AP:   0.4000  -------
# -------  Class: cow              AP:   0.1304  -------
# -------  Class: diningtable      AP:   0.2885  -------
# -------  Class: dog              AP:   0.2739  -------
# -------  Class: horse            AP:   0.4741  -------
# -------  Class: motorbike        AP:   0.4287  -------
# -------  Class: person           AP:   0.7253  -------
# -------  Class: pottedplant      AP:   0.1772  -------
# -------  Class: sheep            AP:   0.2172  -------
# -------  Class: sofa             AP:   0.2687  -------
# -------  Class: train            AP:   0.4699  -------
# -------  Class: tvmonitor        AP:   0.2702  -------
# mAP: 0.3408
# Avg loss: 0.19035796113312245
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.3408214731923129
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.1479042023420334
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.14969272911548615
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.14691539108753204
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.1500718891620636
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.1474880427122116
# -------  Class: aeroplane        AP:   0.5237  -------
# -------  Class: bicycle          AP:   0.3750  -------
# -------  Class: bird             AP:   0.3329  -------
# -------  Class: boat             AP:   0.3062  -------
# -------  Class: bottle           AP:   0.1614  -------
# -------  Class: bus              AP:   0.2319  -------
# -------  Class: car              AP:   0.5219  -------
# -------  Class: cat              AP:   0.3628  -------
# -------  Class: chair            AP:   0.3926  -------
# -------  Class: cow              AP:   0.1480  -------
# -------  Class: diningtable      AP:   0.2910  -------
# -------  Class: dog              AP:   0.2831  -------
# -------  Class: horse            AP:   0.4743  -------
# -------  Class: motorbike        AP:   0.4505  -------
# -------  Class: person           AP:   0.7538  -------
# -------  Class: pottedplant      AP:   0.1673  -------
# -------  Class: sheep            AP:   0.1640  -------
# -------  Class: sofa             AP:   0.2904  -------
# -------  Class: train            AP:   0.5011  -------
# -------  Class: tvmonitor        AP:   0.2352  -------
# mAP: 0.3483
# Avg loss: 0.18795850165188313
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.3483487316947623
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.14683790504932404
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.1463967114686966
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.1460006833076477
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.14247065782546997
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.14924637973308563
# -------  Class: aeroplane        AP:   0.4976  -------
# -------  Class: bicycle          AP:   0.3082  -------
# -------  Class: bird             AP:   0.2959  -------
# -------  Class: boat             AP:   0.3605  -------
# -------  Class: bottle           AP:   0.1438  -------
# -------  Class: bus              AP:   0.2294  -------
# -------  Class: car              AP:   0.5124  -------
# -------  Class: cat              AP:   0.3440  -------
# -------  Class: chair            AP:   0.3641  -------
# -------  Class: cow              AP:   0.1159  -------
# -------  Class: diningtable      AP:   0.2839  -------
# -------  Class: dog              AP:   0.2641  -------
# -------  Class: horse            AP:   0.5123  -------
# -------  Class: motorbike        AP:   0.4081  -------
# -------  Class: person           AP:   0.7460  -------
# -------  Class: pottedplant      AP:   0.1948  -------
# -------  Class: sheep            AP:   0.1830  -------
# -------  Class: sofa             AP:   0.2653  -------
# -------  Class: train            AP:   0.4911  -------
# -------  Class: tvmonitor        AP:   0.2610  -------
# mAP: 0.3391
# Avg loss: 0.18956889472901822
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.33906681315864107
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.14669345319271088
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.13903264701366425
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.14222702383995056
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.14190343022346497
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.1417134702205658
# -------  Class: aeroplane        AP:   0.5534  -------
# -------  Class: bicycle          AP:   0.3955  -------
# -------  Class: bird             AP:   0.2206  -------
# -------  Class: boat             AP:   0.3794  -------
# -------  Class: bottle           AP:   0.1634  -------
# -------  Class: bus              AP:   0.2561  -------
# -------  Class: car              AP:   0.4919  -------
# -------  Class: cat              AP:   0.3635  -------
# -------  Class: chair            AP:   0.3982  -------
# -------  Class: cow              AP:   0.1687  -------
# -------  Class: diningtable      AP:   0.3323  -------
# -------  Class: dog              AP:   0.2949  -------
# -------  Class: horse            AP:   0.5469  -------
# -------  Class: motorbike        AP:   0.4125  -------
# -------  Class: person           AP:   0.7565  -------
# -------  Class: pottedplant      AP:   0.2048  -------
# -------  Class: sheep            AP:   0.2075  -------
# -------  Class: sofa             AP:   0.2701  -------
# -------  Class: train            AP:   0.4666  -------
# -------  Class: tvmonitor        AP:   0.3333  -------
# mAP: 0.3608
# Avg loss: 0.18844509907066823
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.36080457181314707
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.1382618248462677
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.13619084656238556
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.1380990892648697
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.14324131608009338
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.13730616867542267
# -------  Class: aeroplane        AP:   0.5980  -------
# -------  Class: bicycle          AP:   0.3667  -------
# -------  Class: bird             AP:   0.3054  -------
# -------  Class: boat             AP:   0.4006  -------
# -------  Class: bottle           AP:   0.1702  -------
# -------  Class: bus              AP:   0.2899  -------
# -------  Class: car              AP:   0.5600  -------
# -------  Class: cat              AP:   0.3584  -------
# -------  Class: chair            AP:   0.4143  -------
# -------  Class: cow              AP:   0.1483  -------
# -------  Class: diningtable      AP:   0.3470  -------
# -------  Class: dog              AP:   0.3017  -------
# -------  Class: horse            AP:   0.4982  -------
# -------  Class: motorbike        AP:   0.4278  -------
# -------  Class: person           AP:   0.7531  -------
# -------  Class: pottedplant      AP:   0.1771  -------
# -------  Class: sheep            AP:   0.1515  -------
# -------  Class: sofa             AP:   0.2517  -------
# -------  Class: train            AP:   0.5570  -------
# -------  Class: tvmonitor        AP:   0.2985  -------
# mAP: 0.3688
# Avg loss: 0.1831065833568573
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.36878289409688136
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.13709987699985504
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1375178098678589
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.1317761242389679
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.13668422400951385
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.1372426301240921
# -------  Class: aeroplane        AP:   0.5993  -------
# -------  Class: bicycle          AP:   0.3454  -------
# -------  Class: bird             AP:   0.3344  -------
# -------  Class: boat             AP:   0.2928  -------
# -------  Class: bottle           AP:   0.1140  -------
# -------  Class: bus              AP:   0.3434  -------
# -------  Class: car              AP:   0.5687  -------
# -------  Class: cat              AP:   0.3657  -------
# -------  Class: chair            AP:   0.4059  -------
# -------  Class: cow              AP:   0.1700  -------
# -------  Class: diningtable      AP:   0.2632  -------
# -------  Class: dog              AP:   0.2633  -------
# -------  Class: horse            AP:   0.4813  -------
# -------  Class: motorbike        AP:   0.4953  -------
# -------  Class: person           AP:   0.7464  -------
# -------  Class: pottedplant      AP:   0.2108  -------
# -------  Class: sheep            AP:   0.2065  -------
# -------  Class: sofa             AP:   0.2703  -------
# -------  Class: train            AP:   0.4926  -------
# -------  Class: tvmonitor        AP:   0.2847  -------
# mAP: 0.3627
# Avg loss: 0.18832206912338734
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3627009804155039
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.13721245527267456
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.13745294511318207
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.1336803287267685
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.1329164355993271
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.13504648208618164
# -------  Class: aeroplane        AP:   0.6129  -------
# -------  Class: bicycle          AP:   0.3614  -------
# -------  Class: bird             AP:   0.2701  -------
# -------  Class: boat             AP:   0.3937  -------
# -------  Class: bottle           AP:   0.1590  -------
# -------  Class: bus              AP:   0.2221  -------
# -------  Class: car              AP:   0.5646  -------
# -------  Class: cat              AP:   0.3047  -------
# -------  Class: chair            AP:   0.4231  -------
# -------  Class: cow              AP:   0.1715  -------
# -------  Class: diningtable      AP:   0.3748  -------
# -------  Class: dog              AP:   0.2778  -------
# -------  Class: horse            AP:   0.4864  -------
# -------  Class: motorbike        AP:   0.4464  -------
# -------  Class: person           AP:   0.7561  -------
# -------  Class: pottedplant      AP:   0.1688  -------
# -------  Class: sheep            AP:   0.2343  -------
# -------  Class: sofa             AP:   0.2908  -------
# -------  Class: train            AP:   0.4802  -------
# -------  Class: tvmonitor        AP:   0.2764  -------
# mAP: 0.3637
# Avg loss: 0.19160017408430577
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.3637475837680556
# Starting epoch number 101
# Loss for Training on Epoch 101 is 0.13265903294086456
# Starting epoch number 102
# Loss for Training on Epoch 102 is 0.1306678056716919
# Starting epoch number 103
# Loss for Training on Epoch 103 is 0.13217416405677795
# Starting epoch number 104
# Loss for Training on Epoch 104 is 0.12929227948188782
# Starting epoch number 105
# Loss for Training on Epoch 105 is 0.1278700977563858
# -------  Class: aeroplane        AP:   0.5880  -------
# -------  Class: bicycle          AP:   0.3616  -------
# -------  Class: bird             AP:   0.2811  -------
# -------  Class: boat             AP:   0.3836  -------
# -------  Class: bottle           AP:   0.1280  -------
# -------  Class: bus              AP:   0.2813  -------
# -------  Class: car              AP:   0.5318  -------
# -------  Class: cat              AP:   0.3773  -------
# -------  Class: chair            AP:   0.3834  -------
# -------  Class: cow              AP:   0.2011  -------
# -------  Class: diningtable      AP:   0.3264  -------
# -------  Class: dog              AP:   0.2938  -------
# -------  Class: horse            AP:   0.5144  -------
# -------  Class: motorbike        AP:   0.4158  -------
# -------  Class: person           AP:   0.7505  -------
# -------  Class: pottedplant      AP:   0.1889  -------
# -------  Class: sheep            AP:   0.2083  -------
# -------  Class: sofa             AP:   0.2770  -------
# -------  Class: train            AP:   0.5121  -------
# -------  Class: tvmonitor        AP:   0.2454  -------
# mAP: 0.3625
# Avg loss: 0.1887335181236267
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 105 is 0.3624912238361385
# Starting epoch number 106
# Loss for Training on Epoch 106 is 0.1310534030199051
# Starting epoch number 107
# Loss for Training on Epoch 107 is 0.12968909740447998
# Starting epoch number 108
# Loss for Training on Epoch 108 is 0.1269950121641159
# Starting epoch number 109
# Loss for Training on Epoch 109 is 0.12764133512973785
# Starting epoch number 110
# Loss for Training on Epoch 110 is 0.127029150724411
# -------  Class: aeroplane        AP:   0.5760  -------
# -------  Class: bicycle          AP:   0.3469  -------
# -------  Class: bird             AP:   0.3095  -------
# -------  Class: boat             AP:   0.3072  -------
# -------  Class: bottle           AP:   0.1376  -------
# -------  Class: bus              AP:   0.2589  -------
# -------  Class: car              AP:   0.5629  -------
# -------  Class: cat              AP:   0.3598  -------
# -------  Class: chair            AP:   0.4051  -------
# -------  Class: cow              AP:   0.1983  -------
# -------  Class: diningtable      AP:   0.3383  -------
# -------  Class: dog              AP:   0.2581  -------
# -------  Class: horse            AP:   0.5146  -------
# -------  Class: motorbike        AP:   0.4199  -------
# -------  Class: person           AP:   0.7538  -------
# -------  Class: pottedplant      AP:   0.1612  -------
# -------  Class: sheep            AP:   0.1419  -------
# -------  Class: sofa             AP:   0.2148  -------
# -------  Class: train            AP:   0.5239  -------
# -------  Class: tvmonitor        AP:   0.2444  -------
# mAP: 0.3516
# Avg loss: 0.1922088548541069
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 110 is 0.35164730273237843
# Starting epoch number 111
# Loss for Training on Epoch 111 is 0.12750975787639618
# Starting epoch number 112
# Loss for Training on Epoch 112 is 0.12501311302185059
# Starting epoch number 113
# Loss for Training on Epoch 113 is 0.12266566604375839
# Starting epoch number 114
# Loss for Training on Epoch 114 is 0.12733474373817444
# Starting epoch number 115
# Loss for Training on Epoch 115 is 0.12718211114406586
# -------  Class: aeroplane        AP:   0.5719  -------
# -------  Class: bicycle          AP:   0.3665  -------
# -------  Class: bird             AP:   0.2909  -------
# -------  Class: boat             AP:   0.3100  -------
# -------  Class: bottle           AP:   0.1685  -------
# -------  Class: bus              AP:   0.2004  -------
# -------  Class: car              AP:   0.5313  -------
# -------  Class: cat              AP:   0.3726  -------
# -------  Class: chair            AP:   0.4518  -------
# -------  Class: cow              AP:   0.1937  -------
# -------  Class: diningtable      AP:   0.3499  -------
# -------  Class: dog              AP:   0.2942  -------
# -------  Class: horse            AP:   0.5346  -------
# -------  Class: motorbike        AP:   0.4799  -------
# -------  Class: person           AP:   0.7656  -------
# -------  Class: pottedplant      AP:   0.1382  -------
# -------  Class: sheep            AP:   0.1628  -------
# -------  Class: sofa             AP:   0.2755  -------
# -------  Class: train            AP:   0.4729  -------
# -------  Class: tvmonitor        AP:   0.2159  -------
# mAP: 0.3574
# Avg loss: 0.18909068703651427
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 115 is 0.35735862992587564
# Starting epoch number 116
# Loss for Training on Epoch 116 is 0.12415645271539688
# Starting epoch number 117
# Loss for Training on Epoch 117 is 0.12760667502880096
# Starting epoch number 118
# Loss for Training on Epoch 118 is 0.12593983113765717
# Starting epoch number 119
# Loss for Training on Epoch 119 is 0.12510064244270325
# Starting epoch number 120
# Loss for Training on Epoch 120 is 0.1216365322470665
# -------  Class: aeroplane        AP:   0.6380  -------
# -------  Class: bicycle          AP:   0.3809  -------
# -------  Class: bird             AP:   0.3312  -------
# -------  Class: boat             AP:   0.4031  -------
# -------  Class: bottle           AP:   0.1055  -------
# -------  Class: bus              AP:   0.2046  -------
# -------  Class: car              AP:   0.5668  -------
# -------  Class: cat              AP:   0.3836  -------
# -------  Class: chair            AP:   0.3951  -------
# -------  Class: cow              AP:   0.1553  -------
# -------  Class: diningtable      AP:   0.2935  -------
# -------  Class: dog              AP:   0.2673  -------
# -------  Class: horse            AP:   0.5498  -------
# -------  Class: motorbike        AP:   0.5383  -------
# -------  Class: person           AP:   0.7718  -------
# -------  Class: pottedplant      AP:   0.1814  -------
# -------  Class: sheep            AP:   0.1973  -------
# -------  Class: sofa             AP:   0.3087  -------
# -------  Class: train            AP:   0.5456  -------
# -------  Class: tvmonitor        AP:   0.2982  -------
# mAP: 0.3758
# Avg loss: 0.1924890149384737
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 120 is 0.375798997613297
# Starting epoch number 121
# Loss for Training on Epoch 121 is 0.12282653152942657
# Starting epoch number 122
# Loss for Training on Epoch 122 is 0.1256992071866989
# Starting epoch number 123
# Loss for Training on Epoch 123 is 0.12450795620679855
# Starting epoch number 124
# Loss for Training on Epoch 124 is 0.12199900299310684
# Starting epoch number 125
# Loss for Training on Epoch 125 is 0.12213478237390518
# -------  Class: aeroplane        AP:   0.5795  -------
# -------  Class: bicycle          AP:   0.4032  -------
# -------  Class: bird             AP:   0.2957  -------
# -------  Class: boat             AP:   0.3864  -------
# -------  Class: bottle           AP:   0.1423  -------
# -------  Class: bus              AP:   0.2544  -------
# -------  Class: car              AP:   0.5394  -------
# -------  Class: cat              AP:   0.3722  -------
# -------  Class: chair            AP:   0.4223  -------
# -------  Class: cow              AP:   0.1780  -------
# -------  Class: diningtable      AP:   0.3465  -------
# -------  Class: dog              AP:   0.2770  -------
# -------  Class: horse            AP:   0.4984  -------
# -------  Class: motorbike        AP:   0.4765  -------
# -------  Class: person           AP:   0.7547  -------
# -------  Class: pottedplant      AP:   0.1788  -------
# -------  Class: sheep            AP:   0.1968  -------
# -------  Class: sofa             AP:   0.2456  -------
# -------  Class: train            AP:   0.5626  -------
# -------  Class: tvmonitor        AP:   0.3447  -------
# mAP: 0.3727
# Avg loss: 0.19245518520474433
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 125 is 0.37274987035489027
# Starting epoch number 126
# Loss for Training on Epoch 126 is 0.11847569048404694
# Starting epoch number 127
# Loss for Training on Epoch 127 is 0.11929662525653839
# Starting epoch number 128
# Loss for Training on Epoch 128 is 0.12265538424253464
# Starting epoch number 129
# Loss for Training on Epoch 129 is 0.11986034363508224
# Starting epoch number 130
# Loss for Training on Epoch 130 is 0.11756151169538498
# -------  Class: aeroplane        AP:   0.6573  -------
# -------  Class: bicycle          AP:   0.3715  -------
# -------  Class: bird             AP:   0.3304  -------
# -------  Class: boat             AP:   0.3000  -------
# -------  Class: bottle           AP:   0.1653  -------
# -------  Class: bus              AP:   0.2216  -------
# -------  Class: car              AP:   0.5484  -------
# -------  Class: cat              AP:   0.3770  -------
# -------  Class: chair            AP:   0.3789  -------
# -------  Class: cow              AP:   0.1490  -------
# -------  Class: diningtable      AP:   0.3484  -------
# -------  Class: dog              AP:   0.2686  -------
# -------  Class: horse            AP:   0.5150  -------
# -------  Class: motorbike        AP:   0.4545  -------
# -------  Class: person           AP:   0.7664  -------
# -------  Class: pottedplant      AP:   0.1642  -------
# -------  Class: sheep            AP:   0.1595  -------
# -------  Class: sofa             AP:   0.2455  -------
# -------  Class: train            AP:   0.5148  -------
# -------  Class: tvmonitor        AP:   0.2563  -------
# mAP: 0.3596
# Avg loss: 0.19429188445210457
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 130 is 0.35961758129287924
# Starting epoch number 131
# Loss for Training on Epoch 131 is 0.11769566684961319
# Starting epoch number 132
# Loss for Training on Epoch 132 is 0.1158134862780571
# Starting epoch number 133
# Loss for Training on Epoch 133 is 0.11735238879919052
# Starting epoch number 134
# Loss for Training on Epoch 134 is 0.11607044190168381
# Starting epoch number 135
# Loss for Training on Epoch 135 is 0.11644021421670914
# -------  Class: aeroplane        AP:   0.5962  -------
# -------  Class: bicycle          AP:   0.3784  -------
# -------  Class: bird             AP:   0.2964  -------
# -------  Class: boat             AP:   0.3777  -------
# -------  Class: bottle           AP:   0.1371  -------
# -------  Class: bus              AP:   0.2136  -------
# -------  Class: car              AP:   0.5740  -------
# -------  Class: cat              AP:   0.3986  -------
# -------  Class: chair            AP:   0.4032  -------
# -------  Class: cow              AP:   0.1570  -------
# -------  Class: diningtable      AP:   0.3557  -------
# -------  Class: dog              AP:   0.2904  -------
# -------  Class: horse            AP:   0.5427  -------
# -------  Class: motorbike        AP:   0.4253  -------
# -------  Class: person           AP:   0.7719  -------
# -------  Class: pottedplant      AP:   0.1933  -------
# -------  Class: sheep            AP:   0.1994  -------
# -------  Class: sofa             AP:   0.2661  -------
# -------  Class: train            AP:   0.5158  -------
# -------  Class: tvmonitor        AP:   0.2289  -------
# mAP: 0.3661
# Avg loss: 0.1931090634316206
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 135 is 0.36608561769431874
# Starting epoch number 136
# Loss for Training on Epoch 136 is 0.11460085958242416
# Starting epoch number 137
# Loss for Training on Epoch 137 is 0.11169519275426865
# Starting epoch number 138
# Loss for Training on Epoch 138 is 0.11389438062906265
# Starting epoch number 139
# Loss for Training on Epoch 139 is 0.11476826667785645
# Starting epoch number 140
# Loss for Training on Epoch 140 is 0.11285258829593658
# -------  Class: aeroplane        AP:   0.6217  -------
# -------  Class: bicycle          AP:   0.4092  -------
# -------  Class: bird             AP:   0.2952  -------
# -------  Class: boat             AP:   0.4053  -------
# -------  Class: bottle           AP:   0.1654  -------
# -------  Class: bus              AP:   0.1916  -------
# -------  Class: car              AP:   0.5417  -------
# -------  Class: cat              AP:   0.3748  -------
# -------  Class: chair            AP:   0.3896  -------
# -------  Class: cow              AP:   0.1511  -------
# -------  Class: diningtable      AP:   0.4057  -------
# -------  Class: dog              AP:   0.3082  -------
# -------  Class: horse            AP:   0.4834  -------
# -------  Class: motorbike        AP:   0.4547  -------
# -------  Class: person           AP:   0.7679  -------
# -------  Class: pottedplant      AP:   0.1686  -------
# -------  Class: sheep            AP:   0.1861  -------
# -------  Class: sofa             AP:   0.2608  -------
# -------  Class: train            AP:   0.5088  -------
# -------  Class: tvmonitor        AP:   0.3024  -------
# mAP: 0.3696
# Avg loss: 0.19981724098324777
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 140 is 0.3695988888025201
# Starting epoch number 141
# Loss for Training on Epoch 141 is 0.109523706138134
# Starting epoch number 142
# Loss for Training on Epoch 142 is 0.11441695690155029
# Starting epoch number 143
# Loss for Training on Epoch 143 is 0.11190714687108994
# Starting epoch number 144
# Loss for Training on Epoch 144 is 0.11534928530454636
# Starting epoch number 145
# Loss for Training on Epoch 145 is 0.10865568369626999
# -------  Class: aeroplane        AP:   0.5568  -------
# -------  Class: bicycle          AP:   0.3701  -------
# -------  Class: bird             AP:   0.3041  -------
# -------  Class: boat             AP:   0.3982  -------
# -------  Class: bottle           AP:   0.1324  -------
# -------  Class: bus              AP:   0.2460  -------
# -------  Class: car              AP:   0.5902  -------
# -------  Class: cat              AP:   0.3860  -------
# -------  Class: chair            AP:   0.4159  -------
# -------  Class: cow              AP:   0.1444  -------
# -------  Class: diningtable      AP:   0.3933  -------
# -------  Class: dog              AP:   0.3196  -------
# -------  Class: horse            AP:   0.5376  -------
# -------  Class: motorbike        AP:   0.5088  -------
# -------  Class: person           AP:   0.7696  -------
# -------  Class: pottedplant      AP:   0.2120  -------
# -------  Class: sheep            AP:   0.1730  -------
# -------  Class: sofa             AP:   0.2609  -------
# -------  Class: train            AP:   0.5682  -------
# -------  Class: tvmonitor        AP:   0.3002  -------
# mAP: 0.3794
# Avg loss: 0.1944745324552059
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 145 is 0.37937217859510547
# Starting epoch number 146
# Loss for Training on Epoch 146 is 0.11328492313623428
# Starting epoch number 147
# Loss for Training on Epoch 147 is 0.11705906689167023
# Starting epoch number 148
# Loss for Training on Epoch 148 is 0.1113349124789238
# Starting epoch number 149
# Loss for Training on Epoch 149 is 0.11069362610578537
# Starting epoch number 150
# Loss for Training on Epoch 150 is 0.10746552050113678
# -------  Class: aeroplane        AP:   0.6090  -------
# -------  Class: bicycle          AP:   0.3946  -------
# -------  Class: bird             AP:   0.3249  -------
# -------  Class: boat             AP:   0.3930  -------
# -------  Class: bottle           AP:   0.1397  -------
# -------  Class: bus              AP:   0.2875  -------
# -------  Class: car              AP:   0.5601  -------
# -------  Class: cat              AP:   0.3948  -------
# -------  Class: chair            AP:   0.4062  -------
# -------  Class: cow              AP:   0.2011  -------
# -------  Class: diningtable      AP:   0.3563  -------
# -------  Class: dog              AP:   0.2818  -------
# -------  Class: horse            AP:   0.5367  -------
# -------  Class: motorbike        AP:   0.4626  -------
# -------  Class: person           AP:   0.7558  -------
# -------  Class: pottedplant      AP:   0.1784  -------
# -------  Class: sheep            AP:   0.1752  -------
# -------  Class: sofa             AP:   0.2477  -------
# -------  Class: train            AP:   0.4951  -------
# -------  Class: tvmonitor        AP:   0.2591  -------
# mAP: 0.3730
# Avg loss: 0.19628744907677173
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 150 is 0.37297740314739813

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5898  -------
# -------  Class: bicycle          AP:   0.3451  -------
# -------  Class: bird             AP:   0.2820  -------
# -------  Class: boat             AP:   0.3802  -------
# -------  Class: bottle           AP:   0.1419  -------
# -------  Class: bus              AP:   0.3046  -------
# -------  Class: car              AP:   0.5721  -------
# -------  Class: cat              AP:   0.3407  -------
# -------  Class: chair            AP:   0.3931  -------
# -------  Class: cow              AP:   0.1797  -------
# -------  Class: diningtable      AP:   0.2799  -------
# -------  Class: dog              AP:   0.3215  -------
# -------  Class: horse            AP:   0.6246  -------
# -------  Class: motorbike        AP:   0.4719  -------
# -------  Class: person           AP:   0.7843  -------
# -------  Class: pottedplant      AP:   0.2199  -------
# -------  Class: sheep            AP:   0.2346  -------
# -------  Class: sofa             AP:   0.2468  -------
# -------  Class: train            AP:   0.5096  -------
# -------  Class: tvmonitor        AP:   0.2878  -------
# mAP: 0.3755
# Avg loss: 0.19074880064297944
# 0.37550438426232347

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
